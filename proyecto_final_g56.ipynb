# %%
# Importación de las librerías básicas y los métodos asociados a regularización:

#import mis_funciones as aux # Archivo de DesafioLatam para funciones auxilaires.

import cv_error as gfx # Archivo de DesafioLatam para funciones auxilaires.
import numpy as np    # Librería para cálculo numérico y el análisis de datos.
import pandas as pd   # Lib. para cargar DataFrame, manipulación, tratamiento y análisis de datos.
import matplotlib.pyplot as plt  # Lib. para la creación de gráficos en dos dimensiones.
import seaborn as sns  # Lib. para el manejo de gráficas con mejor acabados

import xlrd

from pivottablejs import pivot_ui

pd.options.display.max_columns

from sklearn.linear_model import LogisticRegression, LinearRegression # Calses de Regresion
from sklearn.metrics import classification_report # Modulo de Sklearn para hacer análisis predictivos.

from sklearn.metrics import accuracy_score # Métodos para calcular las métricas ([0-1])
from sklearn.metrics import roc_auc_score # Métodos para calcular el área bajo la curva característica ROC.
from sklearn.metrics import mean_squared_error, r2_score, median_absolute_error #Modulo de Sklearn para los calculos estadísticos.
from sklearn.model_selection import train_test_split # Modulo de Sklearn para entrenar/pruebas a Modelos.

from sklearn.preprocessing import StandardScaler  # Modulo de Sklearn para hacer procesameinto y escalamientos de los datos. 
from pygam import LinearGAM, s


plt.style.use('seaborn') # Gráficos estilo seaborn
plt.style.use('seaborn-whitegrid')
plt.rcParams['figure.figsize']=(10,6) 

import warnings # Librería para omitir las advertencias de actualizaciones de algunos modulos obsoletos.
warnings.filterwarnings('ignore')
# Out:
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:30: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'OLS':
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:32: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif method is 'ridge':
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:34: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif method is 'lasso':
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:36: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif method is 'enet':
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:62: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'OLS':
# d:\3.Informatica-Varios-Cursos\GitHub\notebook_ml\cv_error.py:64: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif method is 'ridge':
# ...

# %%
#! pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip install pivottablejs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
data = pd.read_csv('/Users/elio1/Dataset_csv/anime.csv', delimiter=';')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv('anime.csv', delimiter=';')
#       2 data
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
#                   Descargas de los dataset (archivos de datos tipos csv y xls):
#path_1 = '/Users/elio1/Dataset_csv/anime.csv'
#df_anime= pd.read_csv(path_1)

#path_2 = '/Users/elio1/Dataset_csv/rating.csv'
#df_rating= pd.read_csv(path_2)

# %%
df_anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
df_anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12247 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
print(df_anime.isnull().sum())
print(df_anime[df_anime.isnull().any(axis=1)].shape)
# Out:
# anime_id      0
# name          0
# genre        47
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64
# (277, 7)

# %%
df_anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
df_anime[df_anime['genre'].isnull()]
# Out:
#        anime_id                                            name genre  \
# 2844      33242       IS: Infinite Stratos 2 - Infinite Wedding   NaN
# 3541      33589                                   ViVid Strike!   NaN
# 6040      29765                               Metropolis (2009)   NaN
# 6646      32695                                    Match Shoujo   NaN
# 7018      33187                                Katsudou Shashin   NaN
# 7198      30862                            Yubi wo Nusunda Onna   NaN
# 7335      28987                                        Kamakura   NaN
# 7349      19219                                     Modern No.2   NaN
# 7426      29629                                    Coffee Break   NaN
# 7498      28653                                            Maze   NaN
# 7591      31834                                      Mormorando   NaN
# 7645      31507                           Ari Ningen Monogatari   NaN
# ...

# %%
df_anime[df_anime['type'].isnull()]
# Out:
#        anime_id                              name  \
# 10898     30484                     Steins;Gate 0
# 10900     34437   Code Geass: Fukkatsu no Lelouch
# 10906     33352                 Violet Evergarden
# 10907     33248                  K: Seven Stories
# 10918     33845                  Free! (Shinsaku)
# 10949     33475     Busou Shoujo Machiavellianism
# 10963     31456  Code:Realize: Sousei no Himegimi
# 10983     34332                     Flying Babies
# 10988     34280                           Gamers!
# 10990     34485                        Ganko-chan
# 10991     32455                           Gekidol
# 10994     31433       Ginga Eiyuu Densetsu (2017)
# 10995     28613            Ginga Jinpuu Jinraiger
# 10998     34279                   Grancrest Senki
# 11010     33899                          IDOLiSH7
# 11013     34012                   Isekai Shokudou
# 11041     30448                       Mirai Arise
# 11053     34262            Oushitsu Kyoushi Haine
# ...

# %%
df_anime[df_anime['genre'].isnull()].sum()
# Out:
# anime_id                                              1442939
# name        IS: Infinite Stratos 2 - Infinite WeddingViVid...
# genre                                                       0
# type        SpecialTVMovieONAMovieMovieMovieMovieMovieMovi...
# rating                                                 251.85
# members                                                 25699
# dtype: object

# %%
df_anime[df_anime['genre'].isnull()]
# Out:
#        anime_id                                            name genre  \
# 2844      33242       IS: Infinite Stratos 2 - Infinite Wedding   NaN
# 3541      33589                                   ViVid Strike!   NaN
# 6040      29765                               Metropolis (2009)   NaN
# 6646      32695                                    Match Shoujo   NaN
# 7018      33187                                Katsudou Shashin   NaN
# 7198      30862                            Yubi wo Nusunda Onna   NaN
# 7335      28987                                        Kamakura   NaN
# 7349      19219                                     Modern No.2   NaN
# 7426      29629                                    Coffee Break   NaN
# 7498      28653                                            Maze   NaN
# 7591      31834                                      Mormorando   NaN
# 7645      31507                           Ari Ningen Monogatari   NaN
# ...

# %%
df_anime['genre'].unique()
# Out:
# array(['Drama, Romance, School, Supernatural',
#        'Action, Adventure, Drama, Fantasy, Magic, Military, Shounen',
#        'Action, Comedy, Historical, Parody, Samurai, Sci-Fi, Shounen',
#        ..., 'Hentai, Sports', 'Drama, Romance, School, Yuri',
#        'Hentai, Slice of Life'], dtype=object)

# %%
df_anime[df_anime['rating'].isnull()]
# Out:
#        anime_id                                               name  \
# 8968      34502                                    Inazma Delivery
# 9657      34309  Nananin no Ayakashi: Chimi Chimi Mouryou!! Gen...
# 10896     34096                                     Gintama (2017)
# 10897     34134                                    One Punch Man 2
# 10898     30484                                      Steins;Gate 0
# ...         ...                                                ...
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12279     34491                       Sagurare Otome The Animation
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                                                    genre type episodes  \
# 8968                              Action, Comedy, Sci-Fi   TV       10
# ...

# %%
df_anime.isnull().values.any()
# Out:
# True

# %%
df_rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB

# %%
df_rating.isnull().values.any()
# Out:
# False

# %%
funcs.detecc_de_atributos(df,'Unknown')
